# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
data = {
    'CGPA': [5.5, 6.0, 6.2, 6.5, 6.8, 7.0, 7.2, 7.5, 7.8, 8.0,
             8.2, 8.5, 8.7, 9.0, 9.2],

    'Package': [2.5, 2.8, 3.0, 3.2, 3.5, 3.8, 4.0, 4.3, 4.6, 4.8,
                5.0, 5.5, 5.8, 6.2, 6.5]
}


df = pd.DataFrame(data)

# %%
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#    CGPA  Package
# 0   5.5      2.5
# 1   6.0      2.8
# 2   6.2      3.0
# 3   6.5      3.2
# 4   6.8      3.5

# %%
print("\nDataset shape:")
print(df.shape)
# Out:
# Dataset shape:
# (15, 2)

# %%
print("\nDataset information:")
df.info()
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CGPA     15 non-null     float64
#  1   Package  15 non-null     float64
# dtypes: float64(2)
# memory usage: 372.0 bytes

# %%
print("\nStatistical summary:")
print(df.describe())
print(df.isnull().sum())
# Out:
# Statistical summary:
#             CGPA    Package
# count  15.000000  15.000000
# mean    7.473333   4.366667
# std     1.139214   1.261330
# min     5.500000   2.500000
# 25%     6.650000   3.350000
# 50%     7.500000   4.300000
# 75%     8.350000   5.250000
# max     9.200000   6.500000
# CGPA       0
# Package    0
# dtype: int64

# %%
X = df[['CGPA']]       # Independent variable
y = df['Package']     # Dependent variable

# %%
print("Independent Variable (X): CGPA")
print("Dependent Variable (y): Package")
# Out:
# Independent Variable (X): CGPA
# Dependent Variable (y): Package

# %%
#X = CGPA → input
#y = Package → output/target
# Visualize the relationship
plt.figure(figsize=(8, 5))

plt.scatter(X, y)


plt.xlabel("CGPA")
plt.ylabel("Placement Package (LPA)")
plt.title("CGPA vs Placement Package")


plt.show()

# %%
model.fit(X_train, y_train)


print("Model training completed.")
# Find the slope and intercept
print("Slope (β1):", model.coef_[0])
print("Intercept (β0):", model.intercept_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_771/729576523.py in <cell line: 0>()
# ----> 1 model.fit(X_train, y_train)
#       2
#       3
#       4 print("Model training completed.")
#       5 # Find the slope and intercept
#
# NameError: name 'model' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_771/2068420699.py in <cell line: 0>()
#       1 # Predict the test data
# ----> 2 y_pred = model.predict(X_test)
#       3
#       4
#       5 print("Actual values:")
#
# NameError: name 'model' is not defined

# %%
plt.figure(figsize=(8, 5))


plt.scatter(X, y, label="Actual Data")


plt.plot(X, model.predict(X), label="Regression Line")


plt.xlabel("CGPA")
plt.ylabel("Placement Package (LPA)")
plt.title("Simple Linear Regression: CGPA vs Placement Package")


plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_771/2123256482.py in <cell line: 0>()
#       5
#       6
# ----> 7 plt.plot(X, model.predict(X), label="Regression Line")
#       8
#       9
#
# NameError: name 'model' is not defined
